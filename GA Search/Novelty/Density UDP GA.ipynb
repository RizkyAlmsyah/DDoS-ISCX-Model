# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_curve, auc, precision_score, recall_score
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from numpy import arange
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report

# %%
benign_df = pd.read_csv(r'D:\Kuliah\ProyekAkhir\New Data\resample\Benign_resample.csv')
benign_df.head(2)
# Out:
#     Protocol   Flow Duration   Total Fwd Packets   Total Backward Packets  \
# 0  15.854422       -0.343690           -0.086569                 0.096351
# 1  -0.060352        5.598377            2.253048                 4.681794
#
#    Total Length of Fwd Packets   Total Length of Bwd Packets  \
# 0                     0.142000                      0.002723
# 1                     3.829148                      0.125465
#
#     Fwd Packet Length Max   Fwd Packet Length Min   Fwd Packet Length Mean  \
# 0                0.706619                1.982467                 1.798333
# 1                3.569438               -0.039001                 2.481753
#
#     Fwd Packet Length Std  ...   min_seg_size_forward  Active Mean  \
# 0               -0.034669  ...              -0.059807    -0.095769
# 1                5.125594  ...              -0.059807     1.103561
#
#     Active Std   Active Max   Active Min  Idle Mean   Idle Std   Idle Max  \
# 0    -0.109896    -0.112787    -0.020891  -0.339324  -0.282883  -0.341153
# 1     0.162506     0.515708     1.673959   6.184780  12.942534   8.511326
#
#     Idle Min   Label
# 0  -0.315336       1
# 1   2.479016       1
#
# [2 rows x 79 columns]

# %%
udp_df = pd.read_csv(r'D:\Kuliah\ProyekAkhir\New Data\resample\UDP_resample_4000.csv')
udp_df
# Out:
#        Protocol   Flow Duration   Total Fwd Packets   Total Backward Packets  \
# 0      0.025978       -0.119415           -0.495813                -0.005438
# 1      0.025978        0.019019            0.059450                -0.005438
# 2      0.025978        0.162140            0.614713                -0.005438
# 3      0.025978        0.018732            0.059450                -0.005438
# 4      0.025978        0.162946            0.614713                -0.005438
# ...         ...             ...                 ...                      ...
# 3674   0.025978       -0.119415           -0.495813                -0.005438
# 3675   0.025978        0.018761            0.059450                -0.005438
# 3676   0.025978       -0.119415           -0.495813                -0.005438
# 3677   0.025978       -0.119410           -0.495813                -0.005438
# 3678   0.025978        0.017456            0.059450                -0.005438
#
#       Total Length of Fwd Packets   Total Length of Bwd Packets  \
# 0                       -0.515642                     -0.002646
# 1                        0.019607                     -0.002646
# 2                        0.589549                     -0.002646
# 3                        0.019607                     -0.002646
# 4                        0.589549                     -0.002646
# ...                           ...                           ...
# 3674                    -0.502426                     -0.002646
# 3675                     0.052647                     -0.002646
# 3676                    -0.472690                     -0.002646
# 3677                    -0.472690                     -0.002646
# 3678                     0.019607                     -0.002646
#
#        Fwd Packet Length Max   Fwd Packet Length Min   Fwd Packet Length Mean  \
# 0                  -0.423139                0.371911                 0.083769
# 1                  -0.616152               -0.670846                -0.653085
# 2                   0.155901               -0.879398                -0.696430
# 3                  -0.616152               -0.670846                -0.653085
# 4                   0.155901               -0.879398                -0.696430
# ...                      ...                     ...                      ...
# 3674               -0.165788                0.557290                 0.314939
# 3675                0.027225               -0.670846                -0.364123
# 3676                0.413252                0.974393                 0.835071
# 3677                0.413252                0.974393                 0.835071
# 3678               -0.616152               -0.670846                -0.653085
#
#        Fwd Packet Length Std  ...   min_seg_size_forward  Active Mean  \
# 0                  -0.951297  ...               0.151105    -0.004773
# 1                   0.440479  ...               0.151105    -0.004773
# 2                   1.217554  ...               0.151105    -0.004773
# 3                   0.440479  ...               0.151105    -0.004773
# 4                   1.217554  ...               0.151105    -0.004773
# ...                      ...  ...                    ...          ...
# 3674               -0.951297  ...               0.151105    -0.004773
# 3675                1.154210  ...               0.151105    -0.004773
# 3676               -0.951297  ...               0.151105    -0.004773
# 3677               -0.951297  ...               0.151105    -0.004773
# 3678                0.440479  ...               0.151105    -0.004773
#
#        Active Std   Active Max   Active Min  Idle Mean   Idle Std   Idle Max  \
# 0       -0.003397    -0.005162    -0.004036  -0.007978  -0.002093  -0.007954
# 1       -0.003397    -0.005162    -0.004036  -0.007978  -0.002093  -0.007954
# 2       -0.003397    -0.005162    -0.004036  -0.007978  -0.002093  -0.007954
# 3       -0.003397    -0.005162    -0.004036  -0.007978  -0.002093  -0.007954
# 4       -0.003397    -0.005162    -0.004036  -0.007978  -0.002093  -0.007954
# ...           ...          ...          ...        ...        ...        ...
# 3674    -0.003397    -0.005162    -0.004036  -0.007978  -0.002093  -0.007954
# 3675    -0.003397    -0.005162    -0.004036  -0.007978  -0.002093  -0.007954
# 3676    -0.003397    -0.005162    -0.004036  -0.007978  -0.002093  -0.007954
# 3677    -0.003397    -0.005162    -0.004036  -0.007978  -0.002093  -0.007954
# 3678    -0.003397    -0.005162    -0.004036  -0.007978  -0.002093  -0.007954
#
#        Idle Min   Label
# 0     -0.007811      -1
# 1     -0.007811      -1
# 2     -0.007811      -1
# 3     -0.007811      -1
# 4     -0.007811      -1
# ...         ...     ...
# 3674  -0.007811      -1
# 3675  -0.007811      -1
# 3676  -0.007811      -1
# 3677  -0.007811      -1
# 3678  -0.007811      -1
#
# [3679 rows x 79 columns]

# %%
benign_test_df = pd.read_csv(r'D:\Kuliah\ProyekAkhir\New Data\resample\Benign_resample_4000.csv')

# %%
# novelty detection
df_test = pd.concat([benign_test_df, udp_df], ignore_index=True)
df_train = benign_df

# %%
df_test.columns
# Out:
# Index([' Protocol', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
#        ' Packet Length Std', ' Packet Length Variance', 'FIN Flag Count',
#        ' SYN Flag Count', ' RST Flag Count', ' PSH Flag Count',
#        ' ACK Flag Count', ' URG Flag Count', ' CWE Flag Count',
#        ' ECE Flag Count', ' Down/Up Ratio', ' Average Packet Size',
#        ' Avg Fwd Segment Size', ' Avg Bwd Segment Size',
#        ' Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', ' Fwd Avg Packets/Bulk',
#        ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', ' Subflow Fwd Bytes',
#        ' Subflow Bwd Packets', ' Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        ' Init_Win_bytes_backward', ' act_data_pkt_fwd',
#        ' min_seg_size_forward', 'Active Mean', ' Active Std', ' Active Max',
#        ' Active Min', 'Idle Mean', ' Idle Std', ' Idle Max', ' Idle Min',
#        ' Label'],
#       dtype='object')

# %%
df_test = df_test[['Fwd Packets/s', ' ACK Flag Count', ' Down/Up Ratio', ' Average Packet Size', ' min_seg_size_forward', ' Idle Std', ' Label']]
df_train = df_train[['Fwd Packets/s', ' ACK Flag Count', ' Down/Up Ratio', ' Average Packet Size', ' min_seg_size_forward', ' Idle Std', ' Label']]

# %%
# training_data
X_train = df_train.drop([' Label'], axis=1)
y_train = df_train[' Label']
# testing_data
X_test = df_test.drop([' Label'], axis=1)
y_test = df_test[' Label']

# %%
from scipy.spatial.distance import cdist, euclidean, pdist
from sklearn.cluster import KMeans

class OutlierDetection:
  def __init__(self, benign=None, cluster_n=None):
    if isinstance(benign, pd.DataFrame):
        data = benign.values
    else:
        data = benign
    self.benign = data
    self.cluster_n = cluster_n
    self.kmeans = KMeans(n_clusters=self.cluster_n).fit(self.benign)
    
  def cluster(self):
    labels = self.kmeans.labels_
    centroids = self.kmeans.cluster_centers_
    
    averaged = dict(enumerate(centroids, 0))
    dic= {label: self.benign[labels==label] for label in np.unique(labels)}
    maxDistance = {}
    for i in dic:
      distance = []
      for j in dic[i]:
        distance.append(euclidean(j, averaged[i]))
      maxDistance[i] = np.max(distance)
    
    return maxDistance, averaged
  
  def predict(self, ddos=None):      
    davg, averaged = self.cluster()
    
    anomaly = []
    if isinstance(ddos, pd.DataFrame):
        data = ddos.values
    else:
        data = ddos
        
    for i in data:
        labels = self.kmeans.predict([i])
        dist = euclidean(i, averaged[labels[0]])
        if dist <= davg[labels[0]]:
            anomaly.append(1)
        else:
            anomaly.append(-1) 
    return anomaly

# %%
for i in range(1, 5):
#     #feature extraction
# #     pca = PCA(n_components=8)
# #     df_withpca = pca.fit_transform(df_normalization)
# #     df_ddos_withpca = pca.fit_transform(df_ddos_normalization)
#     #model
    clf = OutlierDetection(benign=X_train, cluster_n=i)
    y_pred_test = clf.predict(X_test)
    print('Cluster : ' + str(i))
    print('---Classification Report---')
    print(classification_report(y_test, y_pred_test))
# Out:
# Cluster : 1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00      3679
#            1       0.52      1.00      0.69      4003
#
#     accuracy                           0.52      7682
#    macro avg       0.26      0.50      0.34      7682
# weighted avg       0.27      0.52      0.36      7682
# C:\Users\rizky\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Cluster : 2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00      3679
#            1       0.52      1.00      0.69      4003
#
#     accuracy                           0.52      7682
#    macro avg       0.26      0.50      0.34      7682
# weighted avg       0.27      0.52      0.36      7682
# C:\Users\rizky\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Cluster : 3
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00      3679
#            1       0.52      1.00      0.69      4003
#
#     accuracy                           0.52      7682
#    macro avg       0.26      0.50      0.34      7682
# weighted avg       0.27      0.52      0.36      7682
# C:\Users\rizky\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Cluster : 4
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00      3679
#            1       0.52      1.00      0.69      4003
#
#     accuracy                           0.52      7682
#    macro avg       0.26      0.50      0.34      7682
# weighted avg       0.27      0.52      0.36      7682
# C:\Users\rizky\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
