# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_curve, auc, precision_score, recall_score
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import LocalOutlierFactor
from numpy import arange
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report

# %%
benign_df = pd.read_csv(r'D:\Kuliah\ProyekAkhir\New Data\resample\Benign_resample.csv')
benign_df.head(2)
# Out:
#     Protocol   Flow Duration   Total Fwd Packets   Total Backward Packets  \
# 0  15.854422       -0.343690           -0.086569                 0.096351
# 1  -0.060352        5.598377            2.253048                 4.681794
#
#    Total Length of Fwd Packets   Total Length of Bwd Packets  \
# 0                     0.142000                      0.002723
# 1                     3.829148                      0.125465
#
#     Fwd Packet Length Max   Fwd Packet Length Min   Fwd Packet Length Mean  \
# 0                0.706619                1.982467                 1.798333
# 1                3.569438               -0.039001                 2.481753
#
#     Fwd Packet Length Std  ...   min_seg_size_forward  Active Mean  \
# 0               -0.034669  ...              -0.059807    -0.095769
# 1                5.125594  ...              -0.059807     1.103561
#
#     Active Std   Active Max   Active Min  Idle Mean   Idle Std   Idle Max  \
# 0    -0.109896    -0.112787    -0.020891  -0.339324  -0.282883  -0.341153
# 1     0.162506     0.515708     1.673959   6.184780  12.942534   8.511326
#
#     Idle Min   Label
# 0  -0.315336       1
# 1   2.479016       1
#
# [2 rows x 79 columns]

# %%
netbios_df = pd.read_csv(r'D:\Kuliah\ProyekAkhir\New Data\resample\NetBios_resample_4000.csv')
netbios_df
# Out:
#        Protocol   Flow Duration   Total Fwd Packets   Total Backward Packets  \
# 0      0.019544       -0.034902           -0.014359                 -0.00594
# 1      0.019544       -0.034870           -0.014359                 -0.00594
# 2      0.019544       -0.034902           -0.014359                 -0.00594
# 3      0.019544       -0.034869           -0.014359                 -0.00594
# 4      0.019544       -0.034869           -0.014359                 -0.00594
# ...         ...             ...                 ...                      ...
# 6644   0.019544       -0.034901           -0.014359                 -0.00594
# 6645   0.019544       -0.034902           -0.014359                 -0.00594
# 6646   0.019544       -0.034902           -0.014359                 -0.00594
# 6647   0.019544       -0.034869           -0.014359                 -0.00594
# 6648   0.019544       -0.034870           -0.014359                 -0.00594
#
#       Total Length of Fwd Packets   Total Length of Bwd Packets  \
# 0                       -0.010963                     -0.003071
# 1                       -0.010963                     -0.003071
# 2                       -0.010963                     -0.003071
# 3                       -0.010963                     -0.003071
# 4                        0.292062                     -0.003071
# ...                           ...                           ...
# 6644                    -0.010963                     -0.003071
# 6645                    -0.010963                     -0.003071
# 6646                    -0.010963                     -0.003071
# 6647                     0.898111                     -0.003071
# 6648                    -0.010963                     -0.003071
#
#        Fwd Packet Length Max   Fwd Packet Length Min   Fwd Packet Length Mean  \
# 0                   0.010276                0.021431                 0.019534
# 1                   0.010276                0.021431                 0.019534
# 2                   0.010276                0.021431                 0.019534
# 3                   0.010276                0.021431                 0.019534
# 4                   1.153700                1.486555                 1.495316
# ...                      ...                     ...                      ...
# 6644                0.010276                0.021431                 0.019534
# 6645                0.010276                0.021431                 0.019534
# 6646                0.010276                0.021431                 0.019534
# 6647                3.440546                4.416803                 4.446881
# 6648                0.010276                0.021431                 0.019534
#
#        Fwd Packet Length Std  ...   min_seg_size_forward  Active Mean  \
# 0                  -0.009313  ...               0.155863    -0.003031
# 1                  -0.009313  ...               0.155863    -0.003031
# 2                  -0.009313  ...               0.155863    -0.003031
# 3                  -0.009313  ...               0.155863    -0.003031
# 4                  -0.009313  ...               0.155863    -0.003031
# ...                      ...  ...                    ...          ...
# 6644               -0.009313  ...               0.155863    -0.003031
# 6645               -0.009313  ...               0.155863    -0.003031
# 6646               -0.009313  ...               0.155863    -0.003031
# 6647               -0.009313  ...               0.155863    -0.003031
# 6648               -0.009313  ...               0.155863    -0.003031
#
#        Active Std   Active Max   Active Min  Idle Mean   Idle Std   Idle Max  \
# 0       -0.001923    -0.003225    -0.002593  -0.034464  -0.002979  -0.034487
# 1       -0.001923    -0.003225    -0.002593  -0.034464  -0.002979  -0.034487
# 2       -0.001923    -0.003225    -0.002593  -0.034464  -0.002979  -0.034487
# 3       -0.001923    -0.003225    -0.002593  -0.034464  -0.002979  -0.034487
# 4       -0.001923    -0.003225    -0.002593  -0.034464  -0.002979  -0.034487
# ...           ...          ...          ...        ...        ...        ...
# 6644    -0.001923    -0.003225    -0.002593  -0.034464  -0.002979  -0.034487
# 6645    -0.001923    -0.003225    -0.002593  -0.034464  -0.002979  -0.034487
# 6646    -0.001923    -0.003225    -0.002593  -0.034464  -0.002979  -0.034487
# 6647    -0.001923    -0.003225    -0.002593  -0.034464  -0.002979  -0.034487
# 6648    -0.001923    -0.003225    -0.002593  -0.034464  -0.002979  -0.034487
#
#        Idle Min   Label
# 0     -0.034441      -1
# 1     -0.034441      -1
# 2     -0.034441      -1
# 3     -0.034441      -1
# 4     -0.034441      -1
# ...         ...     ...
# 6644  -0.034441      -1
# 6645  -0.034441      -1
# 6646  -0.034441      -1
# 6647  -0.034441      -1
# 6648  -0.034441      -1
#
# [6649 rows x 79 columns]

# %%
benign_test_df = pd.read_csv(r'D:\Kuliah\ProyekAkhir\New Data\resample\Benign_resample_4000.csv')

# %%
# novelty detection
df_test = pd.concat([benign_test_df, netbios_df], ignore_index=True)
df_train = benign_df

# %%
df_test = df_test[[' Flow Packets/s', ' ACK Flag Count', ' Bwd Avg Packets/Bulk', ' Idle Std',' Label']]
df_train = df_train[[' Flow Packets/s', ' ACK Flag Count', ' Bwd Avg Packets/Bulk', ' Idle Std',' Label']]

# %%
# training_data
X_train = df_train.drop([' Label'], axis=1)
y_train = df_train[' Label']
# testing_data
X_test = df_test.drop([' Label'], axis=1)
y_test = df_test[' Label']

# %%
# Novelty detection with 8000 sample balanced
for a in range(1, 10):
    for i in arange(0.1, 0.5, 0.1):
        clf = LocalOutlierFactor(n_neighbors=a, novelty=True, contamination=i)
        clf.fit(X_train)
        y_pred_test = clf.predict(X_test)
        print('Neighbour : ' + str(a))
        print('contamination : ' + str(i))
        print('---Classification Report---')
        print(classification_report(y_test, y_pred_test))
# Out:
# Neighbour : 1
# contamination : 0.1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00      6649
#            1       1.00      1.00      1.00      4003
#
#     accuracy                           1.00     10652
#    macro avg       1.00      1.00      1.00     10652
# weighted avg       1.00      1.00      1.00     10652
#
# Neighbour : 1
# contamination : 0.2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00      6649
#            1       1.00      1.00      1.00      4003
#
#     accuracy                           1.00     10652
#    macro avg       1.00      1.00      1.00     10652
# weighted avg       1.00      1.00      1.00     10652
#
# Neighbour : 1
# contamination : 0.30000000000000004
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00      6649
#            1       1.00      1.00      1.00      4003
#
#     accuracy                           1.00     10652
#    macro avg       1.00      1.00      1.00     10652
# weighted avg       1.00      1.00      1.00     10652
#
# Neighbour : 1
# contamination : 0.4
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00      6649
#            1       1.00      1.00      1.00      4003
#
#     accuracy                           1.00     10652
#    macro avg       1.00      1.00      1.00     10652
# weighted avg       1.00      1.00      1.00     10652
#
# Neighbour : 2
# contamination : 0.1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.98      1.00      0.99      6649
#            1       1.00      0.97      0.99      4003
#
#     accuracy                           0.99     10652
#    macro avg       0.99      0.99      0.99     10652
# weighted avg       0.99      0.99      0.99     10652
#
# Neighbour : 2
# contamination : 0.2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.96      1.00      0.98      6649
#            1       1.00      0.93      0.96      4003
#
#     accuracy                           0.97     10652
#    macro avg       0.98      0.96      0.97     10652
# weighted avg       0.97      0.97      0.97     10652
#
# Neighbour : 2
# contamination : 0.30000000000000004
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.95      1.00      0.97      6649
#            1       1.00      0.91      0.96      4003
#
#     accuracy                           0.97     10652
#    macro avg       0.98      0.96      0.96     10652
# weighted avg       0.97      0.97      0.97     10652
#
# Neighbour : 2
# contamination : 0.4
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.94      1.00      0.97      6649
#            1       1.00      0.90      0.95      4003
#
#     accuracy                           0.96     10652
#    macro avg       0.97      0.95      0.96     10652
# weighted avg       0.96      0.96      0.96     10652
#
# Neighbour : 3
# contamination : 0.1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.97      1.00      0.99      6649
#            1       1.00      0.96      0.98      4003
#
#     accuracy                           0.98     10652
#    macro avg       0.99      0.98      0.98     10652
# weighted avg       0.98      0.98      0.98     10652
#
# Neighbour : 3
# contamination : 0.2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.95      1.00      0.97      6649
#            1       1.00      0.91      0.95      4003
#
#     accuracy                           0.97     10652
#    macro avg       0.97      0.95      0.96     10652
# weighted avg       0.97      0.97      0.97     10652
#
# Neighbour : 3
# contamination : 0.30000000000000004
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.93      1.00      0.96      6649
#            1       1.00      0.87      0.93      4003
#
#     accuracy                           0.95     10652
#    macro avg       0.96      0.94      0.95     10652
# weighted avg       0.95      0.95      0.95     10652
#
# Neighbour : 3
# contamination : 0.4
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.91      1.00      0.95      6649
#            1       1.00      0.83      0.91      4003
#
#     accuracy                           0.94     10652
#    macro avg       0.95      0.92      0.93     10652
# weighted avg       0.94      0.94      0.93     10652
#
# Neighbour : 4
# contamination : 0.1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.97      1.00      0.99      6649
#            1       1.00      0.95      0.97      4003
#
#     accuracy                           0.98     10652
#    macro avg       0.99      0.98      0.98     10652
# weighted avg       0.98      0.98      0.98     10652
#
# Neighbour : 4
# contamination : 0.2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.94      1.00      0.97      6649
#            1       1.00      0.89      0.94      4003
#
#     accuracy                           0.96     10652
#    macro avg       0.97      0.95      0.96     10652
# weighted avg       0.96      0.96      0.96     10652
#
# Neighbour : 4
# contamination : 0.30000000000000004
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.91      1.00      0.95      6649
#            1       1.00      0.83      0.91      4003
#
#     accuracy                           0.94     10652
#    macro avg       0.95      0.92      0.93     10652
# weighted avg       0.94      0.94      0.94     10652
#
# Neighbour : 4
# contamination : 0.4
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.89      1.00      0.94      6649
#            1       1.00      0.78      0.88      4003
#
#     accuracy                           0.92     10652
#    macro avg       0.94      0.89      0.91     10652
# weighted avg       0.93      0.92      0.92     10652
#
# Neighbour : 5
# contamination : 0.1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.97      1.00      0.98      6649
#            1       1.00      0.95      0.97      4003
#
#     accuracy                           0.98     10652
#    macro avg       0.98      0.97      0.98     10652
# weighted avg       0.98      0.98      0.98     10652
#
# Neighbour : 5
# contamination : 0.2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.93      1.00      0.96      6649
#            1       1.00      0.88      0.93      4003
#
#     accuracy                           0.95     10652
#    macro avg       0.97      0.94      0.95     10652
# weighted avg       0.96      0.95      0.95     10652
#
# Neighbour : 5
# contamination : 0.30000000000000004
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.90      1.00      0.95      6649
#            1       1.00      0.82      0.90      4003
#
#     accuracy                           0.93     10652
#    macro avg       0.95      0.91      0.92     10652
# weighted avg       0.94      0.93      0.93     10652
#
# Neighbour : 5
# contamination : 0.4
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.87      1.00      0.93      6649
#            1       1.00      0.76      0.86      4003
#
#     accuracy                           0.91     10652
#    macro avg       0.94      0.88      0.90     10652
# weighted avg       0.92      0.91      0.91     10652
#
# Neighbour : 6
# contamination : 0.1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.96      1.00      0.98      6649
#            1       1.00      0.94      0.97      4003
#
#     accuracy                           0.98     10652
#    macro avg       0.98      0.97      0.98     10652
# weighted avg       0.98      0.98      0.98     10652
# Neighbour : 6
# contamination : 0.2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.93      1.00      0.96      6649
#            1       1.00      0.87      0.93      4003
#
#     accuracy                           0.95     10652
#    macro avg       0.96      0.93      0.95     10652
# weighted avg       0.95      0.95      0.95     10652
#
# Neighbour : 6
# contamination : 0.30000000000000004
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.89      1.00      0.94      6649
#            1       1.00      0.80      0.89      4003
#
#     accuracy                           0.92     10652
#    macro avg       0.95      0.90      0.91     10652
# weighted avg       0.93      0.92      0.92     10652
#
# Neighbour : 6
# contamination : 0.4
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.86      1.00      0.93      6649
#            1       1.00      0.73      0.85      4003
#
#     accuracy                           0.90     10652
#    macro avg       0.93      0.87      0.89     10652
# weighted avg       0.91      0.90      0.90     10652
#
# Neighbour : 7
# contamination : 0.1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.96      1.00      0.98      6649
#            1       1.00      0.93      0.97      4003
#
#     accuracy                           0.98     10652
#    macro avg       0.98      0.97      0.97     10652
# weighted avg       0.98      0.98      0.98     10652
#
# Neighbour : 7
# contamination : 0.2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.92      1.00      0.96      6649
#            1       1.00      0.87      0.93      4003
#
#     accuracy                           0.95     10652
#    macro avg       0.96      0.93      0.94     10652
# weighted avg       0.95      0.95      0.95     10652
#
# Neighbour : 7
# contamination : 0.30000000000000004
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.89      1.00      0.94      6649
#            1       1.00      0.79      0.88      4003
#
#     accuracy                           0.92     10652
#    macro avg       0.94      0.89      0.91     10652
# weighted avg       0.93      0.92      0.92     10652
#
# Neighbour : 7
# contamination : 0.4
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.85      1.00      0.92      6649
#            1       1.00      0.71      0.83      4003
#
#     accuracy                           0.89     10652
#    macro avg       0.93      0.85      0.87     10652
# weighted avg       0.91      0.89      0.89     10652
#
# Neighbour : 8
# contamination : 0.1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.96      1.00      0.98      6649
#            1       1.00      0.93      0.96      4003
#
#     accuracy                           0.97     10652
#    macro avg       0.98      0.96      0.97     10652
# weighted avg       0.97      0.97      0.97     10652
#
# Neighbour : 8
# contamination : 0.2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.92      1.00      0.96      6649
#            1       1.00      0.85      0.92      4003
#
#     accuracy                           0.94     10652
#    macro avg       0.96      0.93      0.94     10652
# weighted avg       0.95      0.94      0.94     10652
#
# Neighbour : 8
# contamination : 0.30000000000000004
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.88      1.00      0.94      6649
#            1       1.00      0.77      0.87      4003
#
#     accuracy                           0.91     10652
#    macro avg       0.94      0.89      0.90     10652
# weighted avg       0.92      0.91      0.91     10652
#
# Neighbour : 8
# contamination : 0.4
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.85      1.00      0.92      6649
#            1       1.00      0.70      0.82      4003
#
#     accuracy                           0.89     10652
#    macro avg       0.92      0.85      0.87     10652
# weighted avg       0.90      0.89      0.88     10652
#
# Neighbour : 9
# contamination : 0.1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.96      1.00      0.98      6649
#            1       1.00      0.92      0.96      4003
#
#     accuracy                           0.97     10652
#    macro avg       0.98      0.96      0.97     10652
# weighted avg       0.97      0.97      0.97     10652
#
# Neighbour : 9
# contamination : 0.2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.92      1.00      0.96      6649
#            1       1.00      0.85      0.92      4003
#
#     accuracy                           0.94     10652
#    macro avg       0.96      0.93      0.94     10652
# weighted avg       0.95      0.94      0.94     10652
#
# Neighbour : 9
# contamination : 0.30000000000000004
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.88      1.00      0.93      6649
#            1       1.00      0.76      0.87      4003
#
#     accuracy                           0.91     10652
#    macro avg       0.94      0.88      0.90     10652
# weighted avg       0.92      0.91      0.91     10652
#
# Neighbour : 9
# contamination : 0.4
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.84      1.00      0.91      6649
#            1       1.00      0.69      0.81      4003
#
#     accuracy                           0.88     10652
#    macro avg       0.92      0.84      0.86     10652
# weighted avg       0.90      0.88      0.88     10652
