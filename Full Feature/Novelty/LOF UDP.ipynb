# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_curve, auc, precision_score, recall_score
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import LocalOutlierFactor
from numpy import arange
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report

# %%
benign_df = pd.read_csv(r'D:\Kuliah\ProyekAkhir\New Data\resample\Benign_resample.csv')
udp_df = pd.read_csv(r'D:\Kuliah\ProyekAkhir\New Data\resample\UDP_resample_4000.csv')
benign_test_df = pd.read_csv(r'D:\Kuliah\ProyekAkhir\New Data\resample\Benign_resample_4000.csv')

# %%
# novelty detection
df_test = pd.concat([benign_test_df, udp_df], ignore_index=True)
df_train = benign_df

# training_data
X_train = df_train.drop([' Label'], axis=1)
y_train = df_train[' Label']
# testing_data
X_test = df_test.drop([' Label'], axis=1)
y_test = df_test[' Label']

# %%
df_test.to_csv(r'D:\Kuliah\ProyekAkhir\Data Weka\benign_udp.csv', index = False, header=True)

# %%
# Novelty detection with 8000 sample balanced
for a in range(1, 20):
    for i in arange(0.1, 0.5, 0.1):
        clf = LocalOutlierFactor(n_neighbors=a, novelty=True, contamination=i)
        clf.fit(X_train)
        y_pred_test = clf.predict(X_test)
        print('Neighbour : ' + str(a))
        print('contamination : ' + str(i))
        print('---Classification Report---')
        print(classification_report(y_test, y_pred_test))
# Out:
# Neighbour : 1
# contamination : 0.1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      0.02      0.04      3679
#            1       0.53      1.00      0.69      4003
#
#     accuracy                           0.53      7682
#    macro avg       0.76      0.51      0.36      7682
# weighted avg       0.75      0.53      0.38      7682
#
# Neighbour : 1
# contamination : 0.2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00      3679
#            1       1.00      1.00      1.00      4003
#
#     accuracy                           1.00      7682
#    macro avg       1.00      1.00      1.00      7682
# weighted avg       1.00      1.00      1.00      7682
#
# Neighbour : 1
# contamination : 0.30000000000000004
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00      3679
#            1       1.00      1.00      1.00      4003
#
#     accuracy                           1.00      7682
#    macro avg       1.00      1.00      1.00      7682
# weighted avg       1.00      1.00      1.00      7682
#
# Neighbour : 1
# contamination : 0.4
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00      3679
#            1       1.00      1.00      1.00      4003
#
#     accuracy                           1.00      7682
#    macro avg       1.00      1.00      1.00      7682
# weighted avg       1.00      1.00      1.00      7682
#
# Neighbour : 2
# contamination : 0.1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.97      1.00      0.98      3679
#            1       1.00      0.97      0.98      4003
#
#     accuracy                           0.98      7682
#    macro avg       0.98      0.98      0.98      7682
# weighted avg       0.98      0.98      0.98      7682
#
# Neighbour : 2
# contamination : 0.2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.92      1.00      0.96      3679
#            1       1.00      0.92      0.96      4003
#
#     accuracy                           0.96      7682
#    macro avg       0.96      0.96      0.96      7682
# weighted avg       0.96      0.96      0.96      7682
#
# Neighbour : 2
# contamination : 0.30000000000000004
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.87      1.00      0.93      3679
#            1       1.00      0.86      0.92      4003
#
#     accuracy                           0.93      7682
#    macro avg       0.93      0.93      0.93      7682
# weighted avg       0.94      0.93      0.93      7682
#
# Neighbour : 2
# contamination : 0.4
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.84      1.00      0.91      3679
#            1       1.00      0.82      0.90      4003
#
#     accuracy                           0.91      7682
#    macro avg       0.92      0.91      0.91      7682
# weighted avg       0.92      0.91      0.91      7682
#
# Neighbour : 3
# contamination : 0.1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.94      1.00      0.97      3679
#            1       1.00      0.95      0.97      4003
#
#     accuracy                           0.97      7682
#    macro avg       0.97      0.97      0.97      7682
# weighted avg       0.97      0.97      0.97      7682
#
# Neighbour : 3
# contamination : 0.2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.89      1.00      0.94      3679
#            1       1.00      0.89      0.94      4003
#
#     accuracy                           0.94      7682
#    macro avg       0.95      0.94      0.94      7682
# weighted avg       0.95      0.94      0.94      7682
#
# Neighbour : 3
# contamination : 0.30000000000000004
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.83      1.00      0.91      3679
#            1       1.00      0.81      0.90      4003
#
#     accuracy                           0.90      7682
#    macro avg       0.92      0.91      0.90      7682
# weighted avg       0.92      0.90      0.90      7682
#
# Neighbour : 3
# contamination : 0.4
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.79      1.00      0.88      3679
#            1       1.00      0.75      0.86      4003
#
#     accuracy                           0.87      7682
#    macro avg       0.89      0.88      0.87      7682
# weighted avg       0.90      0.87      0.87      7682
#
# Neighbour : 4
# contamination : 0.1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.93      1.00      0.97      3679
#            1       1.00      0.94      0.97      4003
#
#     accuracy                           0.97      7682
#    macro avg       0.97      0.97      0.97      7682
# weighted avg       0.97      0.97      0.97      7682
#
# Neighbour : 4
# contamination : 0.2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.87      1.00      0.93      3679
#            1       1.00      0.87      0.93      4003
#
#     accuracy                           0.93      7682
#    macro avg       0.94      0.93      0.93      7682
# weighted avg       0.94      0.93      0.93      7682
#
# Neighbour : 4
# contamination : 0.30000000000000004
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.82      1.00      0.90      3679
#            1       1.00      0.80      0.89      4003
#
#     accuracy                           0.89      7682
#    macro avg       0.91      0.90      0.89      7682
# weighted avg       0.91      0.89      0.89      7682
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-65ed5c977c41> in <module>
#       4         clf = LocalOutlierFactor(n_neighbors=a, novelty=True, contamination=i)
#       5         clf.fit(X_train)
# ----> 6         y_pred_test = clf.predict(X_test)
#       7         print('Neighbour : ' + str(a))
#       8         print('contamination : ' + str(i))
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_lof.py in _predict(self, X)
#     340             X = check_array(X, accept_sparse='csr')
#     341             is_inlier = np.ones(X.shape[0], dtype=int)
# --> 342             is_inlier[self.decision_function(X) < 0] = -1
#     343         else:
#     344             is_inlier = np.ones(self.n_samples_fit_, dtype=int)
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_lof.py in _decision_function(self, X)
#     410         """
#     411
# --> 412         return self._score_samples(X) - self.offset_
#     413
#     414     @property
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_lof.py in _score_samples(self, X)
#     479
#     480         distances_X, neighbors_indices_X = (
# --> 481             self.kneighbors(X, n_neighbors=self.n_neighbors_))
#     482         X_lrd = self._local_reachability_density(distances_X,
#     483                                                  neighbors_indices_X)
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1027             # remaining jobs.
#    1028             self._iterating = False
# -> 1029             if self.dispatch_one_batch(iterator):
#    1030                 self._iterating = self._original_iterator is not None
#    1031
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# KeyboardInterrupt:
