# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_curve, auc, precision_score, recall_score
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from numpy import arange
from sklearn.metrics import classification_report

# %%
benign_df = pd.read_csv(r'D:\Kuliah\ProyekAkhir\New Data\resample\Benign_resample.csv')
benign_df.head(2)
# Out:
#     Protocol   Flow Duration   Total Fwd Packets   Total Backward Packets  \
# 0  15.854422       -0.343690           -0.086569                 0.096351
# 1  -0.060352        5.598377            2.253048                 4.681794
#
#    Total Length of Fwd Packets   Total Length of Bwd Packets  \
# 0                     0.142000                      0.002723
# 1                     3.829148                      0.125465
#
#     Fwd Packet Length Max   Fwd Packet Length Min   Fwd Packet Length Mean  \
# 0                0.706619                1.982467                 1.798333
# 1                3.569438               -0.039001                 2.481753
#
#     Fwd Packet Length Std  ...   min_seg_size_forward  Active Mean  \
# 0               -0.034669  ...              -0.059807    -0.095769
# 1                5.125594  ...              -0.059807     1.103561
#
#     Active Std   Active Max   Active Min  Idle Mean   Idle Std   Idle Max  \
# 0    -0.109896    -0.112787    -0.020891  -0.339324  -0.282883  -0.341153
# 1     0.162506     0.515708     1.673959   6.184780  12.942534   8.511326
#
#     Idle Min   Label
# 0  -0.315336       1
# 1   2.479016       1
#
# [2 rows x 79 columns]

# %%
ddos_df = pd.read_csv(r'D:\Kuliah\ProyekAkhir\New Data\resample\DDoS_resample.csv')
ddos_df
# Out:
#         Protocol   Flow Duration   Total Fwd Packets   Total Backward Packets  \
# 0       0.045263       -0.015250           -0.005277                -0.005954
# 1       0.045263       -0.015250           -0.005277                -0.005954
# 2       0.045263       -0.015250           -0.005277                -0.005954
# 3       0.045263       -0.015249           -0.005277                -0.005954
# 4       0.045263       -0.015250           -0.005277                -0.005954
# ...          ...             ...                 ...                      ...
# 29029   2.209517       -0.327036           -0.309612                -0.339661
# 29030   2.209517       -0.327036           -0.309612                -0.339661
# 29031   2.209517       -0.327036           -0.309612                -0.339661
# 29032   2.209517       -0.327036           -0.309612                -0.339661
# 29033   2.209517       -0.327036           -0.309612                -0.339661
#
#        Total Length of Fwd Packets   Total Length of Bwd Packets  \
# 0                         0.289320                     -0.002643
# 1                         0.309328                     -0.002643
# 2                         0.309328                     -0.002643
# 3                         0.309328                     -0.002643
# 4                         0.289320                     -0.002643
# ...                            ...                           ...
# 29029                     0.820881                     -0.010439
# 29030                     0.820881                     -0.010439
# 29031                     0.820881                     -0.010439
# 29032                     0.820881                     -0.010439
# 29033                     0.820881                     -0.010439
#
#         Fwd Packet Length Max   Fwd Packet Length Min  \
# 0                    0.322770                0.323287
# 1                    0.344531                0.345012
# 2                    0.344531                0.345012
# 3                    0.344531                0.345012
# 4                    0.322770                0.323287
# ...                       ...                     ...
# 29029                2.527200                2.846555
# 29030                2.527200                2.846555
# 29031                2.527200                2.846555
# 29032                2.527200                2.846555
# 29033                2.527200                2.846555
#
#         Fwd Packet Length Mean   Fwd Packet Length Std  ...  \
# 0                     0.323284               -0.016174  ...
# 1                     0.345025               -0.016174  ...
# 2                     0.345025               -0.016174  ...
# 3                     0.345025               -0.016174  ...
# 4                     0.323284               -0.016174  ...
# ...                        ...                     ...  ...
# 29029                 2.732269               -0.198358  ...
# 29030                 2.732269               -0.198358  ...
# 29031                 2.732269               -0.198358  ...
# 29032                 2.732269               -0.198358  ...
# 29033                 2.732269               -0.198358  ...
#
#         min_seg_size_forward  Active Mean   Active Std   Active Max  \
# 0                   0.226640    -0.007737    -0.005256    -0.007436
# 1                   0.226640    -0.007737    -0.005256    -0.007436
# 2                   0.226640    -0.007737    -0.005256    -0.007436
# 3                   0.226640    -0.007737    -0.005256    -0.007436
# 4                   0.226646    -0.007737    -0.005256    -0.007436
# ...                      ...          ...          ...          ...
# 29029               0.063244    -0.098072    -0.107270    -0.109441
# 29030               0.063244    -0.098072    -0.107270    -0.109441
# 29031               0.063244    -0.098072    -0.107270    -0.109441
# 29032               0.063244    -0.098072    -0.107270    -0.109441
# 29033               0.063244    -0.098072    -0.107270    -0.109441
#
#         Active Min  Idle Mean   Idle Std   Idle Max   Idle Min   Label
# 0        -0.006370  -0.013105  -0.005207  -0.013185  -0.012838      -1
# 1        -0.006370  -0.013105  -0.005207  -0.013185  -0.012838      -1
# 2        -0.006370  -0.013105  -0.005207  -0.013185  -0.012838      -1
# 3        -0.006370  -0.013105  -0.005207  -0.013185  -0.012838      -1
# 4        -0.006370  -0.013105  -0.005207  -0.013185  -0.012838      -1
# ...            ...        ...        ...        ...        ...     ...
# 29029    -0.015768  -0.315335  -0.268473  -0.315664  -0.295924      -1
# 29030    -0.015768  -0.315335  -0.268473  -0.315664  -0.295924      -1
# 29031    -0.015768  -0.315335  -0.268473  -0.315664  -0.295924      -1
# 29032    -0.015768  -0.315335  -0.268473  -0.315664  -0.295924      -1
# 29033    -0.015768  -0.315335  -0.268473  -0.315664  -0.295924      -1
#
# [29034 rows x 79 columns]

# %%
benign_test_df = pd.read_csv(r'D:\Kuliah\ProyekAkhir\New Data\resample\Benign_resample_4000.csv')

# %%
# novelty detection
df_test = pd.concat([benign_test_df, ddos_df], ignore_index=True)
df_train = benign_df

# training_data
X_train = df_train.drop([' Label'], axis=1)
y_train = df_train[' Label']
# testing_data
X_test = df_test.drop([' Label'], axis=1)
y_test = df_test[' Label']

# %%
from scipy.spatial.distance import cdist, euclidean, pdist
from sklearn.cluster import KMeans

class OutlierDetection:
  def __init__(self, benign=None, cluster_n=None):
    if isinstance(benign, pd.DataFrame):
        data = benign.values
    else:
        data = benign
    self.benign = data
    self.cluster_n = cluster_n
    self.kmeans = KMeans(n_clusters=self.cluster_n).fit(self.benign)
    
  def cluster(self):
    labels = self.kmeans.labels_
    centroids = self.kmeans.cluster_centers_
    
    averaged = dict(enumerate(centroids, 0))
    dic= {label: self.benign[labels==label] for label in np.unique(labels)}
    maxDistance = {}
    for i in dic:
      distance = []
      for j in dic[i]:
        distance.append(euclidean(j, averaged[i]))
      maxDistance[i] = np.max(distance)
    
    return maxDistance, averaged
  
  def predict(self, ddos=None):      
    davg, averaged = self.cluster()
    
    anomaly = []
    if isinstance(ddos, pd.DataFrame):
        data = ddos.values
    else:
        data = ddos
        
    for i in data:
        labels = self.kmeans.predict([i])
        dist = euclidean(i, averaged[labels[0]])
        if dist <= davg[labels[0]]:
            anomaly.append(1)
        else:
            anomaly.append(-1) 
    return anomaly

# %%
for i in range(1, 15):
    clf = OutlierDetection(benign=X_train, cluster_n=i)
    y_pred_test = clf.predict(X_test)
    print('Cluster : ' + str(i))
    print('---Classification Report---')
    print(classification_report(y_test, y_pred_test))
# Out:
# Cluster : 1
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00     29034
#            1       0.12      1.00      0.22      4003
#
#     accuracy                           0.12     33037
#    macro avg       0.06      0.50      0.11     33037
# weighted avg       0.01      0.12      0.03     33037
# C:\Users\rizky\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Cluster : 2
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00     29034
#            1       0.12      1.00      0.22      4003
#
#     accuracy                           0.12     33037
#    macro avg       0.06      0.50      0.11     33037
# weighted avg       0.01      0.12      0.03     33037
# C:\Users\rizky\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Cluster : 3
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00     29034
#            1       0.12      1.00      0.22      4003
#
#     accuracy                           0.12     33037
#    macro avg       0.06      0.50      0.11     33037
# weighted avg       0.01      0.12      0.03     33037
# C:\Users\rizky\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Cluster : 4
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00     29034
#            1       0.12      1.00      0.22      4003
#
#     accuracy                           0.12     33037
#    macro avg       0.06      0.50      0.11     33037
# weighted avg       0.01      0.12      0.03     33037
# C:\Users\rizky\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Cluster : 5
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      0.00      0.00     29034
#            1       0.12      1.00      0.22      4003
#
#     accuracy                           0.12     33037
#    macro avg       0.56      0.50      0.11     33037
# weighted avg       0.89      0.12      0.03     33037
#
# Cluster : 6
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      0.00      0.00     29034
#            1       0.12      1.00      0.22      4003
#
#     accuracy                           0.12     33037
#    macro avg       0.56      0.50      0.11     33037
# weighted avg       0.89      0.12      0.03     33037
#
# Cluster : 7
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      0.00      0.00     29034
#            1       0.12      1.00      0.22      4003
#
#     accuracy                           0.12     33037
#    macro avg       0.56      0.50      0.11     33037
# weighted avg       0.89      0.12      0.03     33037
#
# Cluster : 8
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      0.00      0.00     29034
#            1       0.12      1.00      0.22      4003
#
#     accuracy                           0.12     33037
#    macro avg       0.56      0.50      0.11     33037
# weighted avg       0.89      0.12      0.03     33037
#
# Cluster : 9
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      0.00      0.00     29034
#            1       0.12      1.00      0.22      4003
#
#     accuracy                           0.12     33037
#    macro avg       0.56      0.50      0.11     33037
# weighted avg       0.89      0.12      0.03     33037
#
# Cluster : 10
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      0.00      0.00     29034
#            1       0.12      1.00      0.22      4003
#
#     accuracy                           0.12     33037
#    macro avg       0.56      0.50      0.11     33037
# weighted avg       0.89      0.12      0.03     33037
#
# Cluster : 11
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      0.00      0.00     29034
#            1       0.12      1.00      0.22      4003
#
#     accuracy                           0.12     33037
#    macro avg       0.56      0.50      0.11     33037
# weighted avg       0.89      0.12      0.03     33037
#
# Cluster : 12
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      0.00      0.00     29034
#            1       0.12      1.00      0.22      4003
#
#     accuracy                           0.12     33037
#    macro avg       0.56      0.50      0.11     33037
# weighted avg       0.89      0.12      0.03     33037
#
# Cluster : 13
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      0.00      0.00     29034
#            1       0.12      1.00      0.22      4003
#
#     accuracy                           0.12     33037
#    macro avg       0.56      0.50      0.11     33037
# weighted avg       0.89      0.12      0.03     33037
#
# Cluster : 14
# ---Classification Report---
#               precision    recall  f1-score   support
#
#           -1       1.00      0.00      0.00     29034
#            1       0.12      1.00      0.22      4003
#
#     accuracy                           0.12     33037
#    macro avg       0.56      0.50      0.11     33037
# weighted avg       0.89      0.12      0.03     33037
